# %%
import polars as pl
pl.Config.set_tbl_rows(50)
pl.Config.set_fmt_str_lengths(100)
df = pl.read_parquet('CurProcessorExport-00001.snappy.parquet') ## data from Nov 11th for this account
# df = pl.read_parquet('./ollion-sandbox-cur.snappy.parquet')

# %% [markdown]
# ## EC2 Products

# %%
ec2_non_null_df = df.filter((pl.col('line_item_resource_id').is_not_null())
                            & (pl.col('line_item_product_code').eq('AmazonEC2'))
                            & (pl.col('product_region_code').is_not_null()))
triplets_df = ec2_non_null_df.select(["line_item_product_code", "product_region_code", "line_item_resource_id"])
triplets_df = triplets_df.unique()
triplets_df.sort(["product_region_code", "line_item_resource_id"])
triplets_df

# EBS snapshots ids follow arns with :snapshot/ - Snapshot ID
# EBS volumes start with vol- - Volume ID
# EC2 instances start with i- - Instance ID
# nat gateways ids follow arns with :natgateway/ - Nat Gateway ID
# All else will be marked as Unknown
resource_id_df = triplets_df.with_columns(
    resource_id_type = pl.when(pl.col('line_item_resource_id').str.contains(':snapshot/'))
    .then(pl.lit('Snapshot ID'))
    .when(pl.col('line_item_resource_id').str.starts_with('vol-'))
    .then(pl.lit('Volume ID'))
    .when(pl.col('line_item_resource_id').str.starts_with('i-'))
    .then(pl.lit('Instance ID'))
    .when(pl.col('line_item_resource_id').str.contains(':natgateway/'))
    .then(pl.lit('Nat Gateway ID'))
    .otherwise(pl.lit('Unknown'))
)
# use regex to extract the id from the arn
resource_id_df = resource_id_df.with_columns(
    pl.col("line_item_resource_id").str.replace_all(r'.*:snapshot/', "")
)
resource_id_df = resource_id_df.with_columns(
    pl.col("line_item_resource_id").str.replace_all(r'.*:natgateway/', "")
)
resource_id_df
# Out:
# shape: (704, 4)
# ┌────────────────────────┬─────────────────────┬────────────────────────┬──────────────────┐
# │ line_item_product_code ┆ product_region_code ┆ line_item_resource_id  ┆ resource_id_type │
# │ ---                    ┆ ---                 ┆ ---                    ┆ ---              │
# │ str                    ┆ str                 ┆ str                    ┆ str              │
# ╞════════════════════════╪═════════════════════╪════════════════════════╪══════════════════╡
# │ AmazonEC2              ┆ us-east-1           ┆ vol-098da221120cecd24  ┆ Volume ID        │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0a8104bd639a9e280 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0213191263e290cd3 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-03ee2112634a82ed4 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0a1081a80a34e83dc ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-west-2           ┆ i-00bae9112afebfb94    ┆ Instance ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0bca88c428e5165fe ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-086b34369fa7f0887 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0d5a827c20afc7585 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0f167e1d23a60e15c ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-065aaac08529b4d91 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0fe7284979e0a36f0 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ i-016e2f4a6104e2986    ┆ Instance ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-08e0b2c487cbe8c59 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-075f26d01ee99c2ce ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-057dc98286c432323 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-000d0f1fb075f6893 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-04a5b7bbb8928bc08 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-080e5ab26b57ea6b9 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0324e101513453e6a ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-066e5dd1b1a840ded ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-062e39934592c7986 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-02d1e48e0cddfe2ab ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ vol-05fceb3b685dca6fd  ┆ Volume ID        │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0b3c9e97b16b22cf6 ┆ Snapshot ID      │
# │ …                      ┆ …                   ┆ …                      ┆ …                │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0b8d6160f99cd25ea ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-037e19f991a9ad826 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0a61caa5d3e35db59 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-west-2           ┆ i-0c56c52b433aeeadd    ┆ Instance ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0afa795515a4949df ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0e3cadd581f0c5c5b ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-09854886aaed18981 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-022847e86ba1122f8 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0a35b91216378b6ca ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0db6d61b004de9960 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-073c9c61bfe46ecbf ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0f206b6466ee00a59 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-06acb7639996ad287 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-west-1           ┆ i-0142dbc11f016a637    ┆ Instance ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0fe1eebf937544b6f ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0f7eacc9d88a5462a ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-088857083aac1ed57 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-2           ┆ vol-06936c877b34a88d6  ┆ Volume ID        │
# │ AmazonEC2              ┆ us-east-1           ┆ i-0b9473b3e68f5e9c5    ┆ Instance ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0376b664eb9956b0b ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-099c92536c5f90e3d ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-03ae003c044fb300e ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0ba6b31b5b0b9bf18 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0468a8b8a01b47256 ┆ Snapshot ID      │
# │ AmazonEC2              ┆ us-east-1           ┆ snap-0fcaa86b5afd63338 ┆ Snapshot ID      │
# └────────────────────────┴─────────────────────┴────────────────────────┴──────────────────┘

# %% [markdown]
# ## S3 Products

# %%
s3_non_null_df = df.filter((pl.col('line_item_resource_id').is_not_null())
                            & (pl.col('line_item_product_code').eq('AmazonS3'))
                            & (pl.col('product_region_code').is_not_null()))
triplets_df = s3_non_null_df.select(["line_item_product_code", "product_region_code", "line_item_resource_id"])
triplets_df = triplets_df.unique()
triplets_df.sort(["product_region_code", "line_item_resource_id"])
triplets_df

# S3 bucket names are the resource id
resource_id_df = triplets_df.with_columns(
    resource_id_type = pl.lit('Bucket Name')
)
resource_id_df
# Out:
# shape: (196, 4)
# ┌────────────────────────┬─────────────────────┬────────────────────────────────┬──────────────────┐
# │ line_item_product_code ┆ product_region_code ┆ line_item_resource_id          ┆ resource_id_type │
# │ ---                    ┆ ---                 ┆ ---                            ┆ ---              │
# │ str                    ┆ str                 ┆ str                            ┆ str              │
# ╞════════════════════════╪═════════════════════╪════════════════════════════════╪══════════════════╡
# │ AmazonS3               ┆ us-east-2           ┆ 2w-ingestion-engine-snowpipe-d ┆ Bucket Name      │
# │                        ┆                     ┆ ata-stage                      ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ cloudvod-logsbucket-1b0h2h4feg ┆ Bucket Name      │
# │                        ┆                     ┆ l28-logs6819bb44-pxgkuthpxe9r  ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ aws-workspaces-latency-test202 ┆ Bucket Name      │
# │                        ┆                     ┆ 41017161752423400000001        ┆                  │
# │ AmazonS3               ┆ us-west-2           ┆ a-test-bucket-ot-ss-raw-no-key ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ sagemaker-us-east-1-1879408568 ┆ Bucket Name      │
# │                        ┆                     ┆ 53                             ┆                  │
# │ AmazonS3               ┆ us-west-1           ┆ fintech-eks-terraform-bucket   ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ winson-test-sgw-bucket-1       ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ 187940856853-us-east-1-athena- ┆ Bucket Name      │
# │                        ┆                     ┆ results-bucket-xgmzjqwh2c      ┆                  │
# │ AmazonS3               ┆ us-east-2           ┆ testbucket2222333332222222     ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-2           ┆ customizationsforctsolut-custo ┆ Bucket Name      │
# │                        ┆                     ┆ mcontroltowers3acce-1vbft8g61r ┆                  │
# │                        ┆                     ┆ 8hz                            ┆                  │
# │ AmazonS3               ┆ us-west-2           ┆ johnwebbtest                   ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ am-migrate-to-gcp-test         ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ mytestbucket-destination-1     ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ bigquerys3nr                   ┆ Bucket Name      │
# │ AmazonS3               ┆ us-west-2           ┆ awsbilling-187940856853        ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ webidf-appbucket-1j9j54mrogksd ┆ Bucket Name      │
# │ AmazonS3               ┆ us-west-2           ┆ bnolan-ecsv2-testing-remote-st ┆ Bucket Name      │
# │                        ┆                     ┆ ate-s3                         ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ sql-server-backup-bucket-mk    ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ ae-json-test-20231130          ┆ Bucket Name      │
# │ AmazonS3               ┆ us-west-2           ┆ test-bucket-recommender        ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ aws-sam-cli-managed-dev-pi-art ┆ Bucket Name      │
# │                        ┆                     ┆ ifactsloggingbucket-gq7wp77uxw ┆                  │
# │                        ┆                     ┆ le                             ┆                  │
# │ AmazonS3               ┆ us-west-2           ┆ 2022-cloud-econ-gcp-data       ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-2           ┆ 2022-intern-tommysubaric       ┆ Bucket Name      │
# │ AmazonS3               ┆ us-west-1           ┆ cf-templates-rr5ff5n34f41-us-w ┆ Bucket Name      │
# │                        ┆                     ┆ est-1                          ┆                  │
# │ AmazonS3               ┆ us-east-2           ┆ ingestion-framework-alex       ┆ Bucket Name      │
# │ …                      ┆ …                   ┆ …                              ┆ …                │
# │ AmazonS3               ┆ us-east-1           ┆ myawsdgbucket                  ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-2           ┆ aws-ingestion-framework-config ┆ Bucket Name      │
# │                        ┆                     ┆ s-alex-dev                     ┆                  │
# │ AmazonS3               ┆ us-west-2           ┆ db-80b1c0e1c2f1bf9f2288eed14f9 ┆ Bucket Name      │
# │                        ┆                     ┆ ba96f-s3-root-bucket           ┆                  │
# │ AmazonS3               ┆ us-west-2           ┆ a-test-bucket-ot-ss-processed  ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-2           ┆ cdk-hnb659fds-assets-187940856 ┆ Bucket Name      │
# │                        ┆                     ┆ 853-us-east-2                  ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ lenovo-china-cur               ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ 187940856853-us-east-1-athena- ┆ Bucket Name      │
# │                        ┆                     ┆ results-bucket-g392no5v9i      ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ ets-test-tf-bucket             ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ tagboard-recommender-dev--serv ┆ Bucket Name      │
# │                        ┆                     ┆ erlessdeploymentbuck-4ygbiopbi ┆                  │
# │                        ┆                     ┆ pjf                            ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ aws-athena-query-results-18794 ┆ Bucket Name      │
# │                        ┆                     ┆ 0856853-us-east-1              ┆                  │
# │ AmazonS3               ┆ us-east-2           ┆ evelyn-aws-ingestion-framework ┆ Bucket Name      │
# │                        ┆                     ┆ -configs-evelyn                ┆                  │
# │ AmazonS3               ┆ us-west-2           ┆ dhart.4-8-2022.ssm.patching.bu ┆ Bucket Name      │
# │                        ┆                     ┆ ket                            ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ patchtest2w                    ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ aws-sam-cli-managed-default-sa ┆ Bucket Name      │
# │                        ┆                     ┆ mclisourcebucket-5179zbu9s5rf  ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ test-bucket-ritm10636942       ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ vpc-flow-logs-test-12345       ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-2           ┆ 2w-ingestion-engine-configs-al ┆ Bucket Name      │
# │                        ┆                     ┆ ex-test-sls                    ┆                  │
# │ AmazonS3               ┆ us-west-2           ┆ cdk-hnb659fds-assets-187940856 ┆ Bucket Name      │
# │                        ┆                     ┆ 853-us-west-2                  ┆                  │
# │ AmazonS3               ┆ us-west-2           ┆ tagboardatalake1-dev           ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-1           ┆ cw-monitoring-s3-lambdadeploym ┆ Bucket Name      │
# │                        ┆                     ┆ entbucket-akbam21dnjy3         ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ destination-bucket-9989        ┆ Bucket Name      │
# │ AmazonS3               ┆ us-east-2           ┆ serverless-deployment-ingestio ┆ Bucket Name      │
# │                        ┆                     ┆ nframework                     ┆                  │
# │ AmazonS3               ┆ us-west-2           ┆ aws-sam-cli-managed-default-sa ┆ Bucket Name      │
# │                        ┆                     ┆ mclisourcebucket-ivqxubzroteh  ┆                  │
# │ AmazonS3               ┆ us-east-1           ┆ curprocessorstack-curbucket1ac ┆ Bucket Name      │
# │                        ┆                     ┆ ad2a6-josrlebznwwi             ┆                  │
# │ AmazonS3               ┆ us-east-2           ┆ alb-agencymatrix-dev-us-east-2 ┆ Bucket Name      │
# │                        ┆                     ┆ -log20231019164858239200000003 ┆                  │
# └────────────────────────┴─────────────────────┴────────────────────────────────┴──────────────────┘

# %% [markdown]
# ##

# %% [markdown]
# ## Lambda Products

# %%
## get triplets of product code, region code, and resource id for Usage and SavingsPlanCoveredUsage
lam_df = df.filter((pl.col('line_item_product_code').eq('AWSLambda')) &
                (pl.col('product_region_code').is_not_null()) &
                (pl.col('line_item_resource_id').is_not_null())
)
triplets_df = lam_df.select(["line_item_product_code", "product_region_code", "line_item_resource_id"])
triplets_df = triplets_df.unique()
triplets_df.sort(["product_region_code", "line_item_resource_id"])

# Lambda tags are extracted based on the full arn in the resource id
resource_id_df = triplets_df.with_columns(
    resource_id_type = pl.lit('Lambda ARN')
)
resource_id_df
# Out:
# shape: (63, 4)
# ┌────────────────────────┬─────────────────────┬────────────────────────────────┬──────────────────┐
# │ line_item_product_code ┆ product_region_code ┆ line_item_resource_id          ┆ resource_id_type │
# │ ---                    ┆ ---                 ┆ ---                            ┆ ---              │
# │ str                    ┆ str                 ┆ str                            ┆ str              │
# ╞════════════════════════╪═════════════════════╪════════════════════════════════╪══════════════════╡
# │ AWSLambda              ┆ us-west-2           ┆ arn:aws:lambda:us-west-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -offers-west-2-1f6976a4-b647-4 ┆                  │
# │                        ┆                     ┆ 7a2-88a4-3…                    ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -join-east-2-1a5d8ca7-d693-40e ┆                  │
# │                        ┆                     ┆ 7-81cc-818…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:identify_diff ┆                  │
# │                        ┆                     ┆ erences_fn                     ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-ckr-con ┆                  │
# │                        ┆                     ┆ tact-us-east-2-4c254993-79db-4 ┆                  │
# │                        ┆                     ┆ 262-ad5b-9…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:dynamo_sessio ┆                  │
# │                        ┆                     ┆ n_record_fn                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:CloudWatchAut ┆                  │
# │                        ┆                     ┆ oAlarms                        ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:doc_ingestion ┆                  │
# │                        ┆                     ┆ _fn                            ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:CdkStepdefnSt ┆                  │
# │                        ┆                     ┆ arterStack-ScheduledLambdaSche ┆                  │
# │                        ┆                     ┆ duledLa-5L…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:imageBuildFai ┆                  │
# │                        ┆                     ┆ ledTest                        ┆                  │
# │ AWSLambda              ┆ us-west-1           ┆ arn:aws:lambda:us-west-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -order-west-1-0a130140-2c70-42 ┆                  │
# │                        ┆                     ┆ f6-bf08-af…                    ┆                  │
# │ AWSLambda              ┆ us-west-1           ┆ arn:aws:lambda:us-west-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -offers-west-1-da4c92f7-5204-4 ┆                  │
# │                        ┆                     ┆ 353-b33e-d…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:CurProcessorS ┆                  │
# │                        ┆                     ┆ tack-CURProcessingLambda1529E4 ┆                  │
# │                        ┆                     ┆ 09-w4JkLjl…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:legal-ai-dev- ┆                  │
# │                        ┆                     ┆ doc-ingestion-61be06b          ┆                  │
# │ AWSLambda              ┆ us-west-1           ┆ arn:aws:lambda:us-west-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -join-west-1-b6db9b42-5f89-47f ┆                  │
# │                        ┆                     ┆ a-8e60-762…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:lamda-di-lega ┆                  │
# │                        ┆                     ┆ l-ai-identify-differences      ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -gc-east-2-7af65ed8-9ae4-4b20- ┆                  │
# │                        ┆                     ┆ 8330-a0dd0…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:CdkStepdefnSt ┆                  │
# │                        ┆                     ┆ arterStack-MyLambdaConstructMy ┆                  │
# │                        ┆                     ┆ LambdaF-9X…                    ┆                  │
# │ AWSLambda              ┆ us-west-2           ┆ arn:aws:lambda:us-west-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-ckr-con ┆                  │
# │                        ┆                     ┆ tact-us-west-2-9b7fe7bc-f811-4 ┆                  │
# │                        ┆                     ┆ b46-9fa9-d…                    ┆                  │
# │ AWSLambda              ┆ us-west-1           ┆ arn:aws:lambda:us-west-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -gc-west-1-fa0da12b-9ee1-4783- ┆                  │
# │                        ┆                     ┆ a3e2-fc11f…                    ┆                  │
# │ AWSLambda              ┆ us-west-2           ┆ arn:aws:lambda:us-west-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:aaguiar-ad-re ┆                  │
# │                        ┆                     ┆ ader-pwsh                      ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:2ndwatchtestu ┆                  │
# │                        ┆                     ┆ serreport                      ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:identify-diff ┆                  │
# │                        ┆                     ┆ erences-fn                     ┆                  │
# │ AWSLambda              ┆ us-west-2           ┆ arn:aws:lambda:us-west-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -locati-west-2-ff86051e-bf66-4 ┆                  │
# │                        ┆                     ┆ b48-8009-b…                    ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:ingestion-eng ┆                  │
# │                        ┆                     ┆ ine-dev-get-job-configs        ┆                  │
# │ AWSLambda              ┆ us-west-1           ┆ arn:aws:lambda:us-west-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -locati-west-1-8969c83b-ea31-4 ┆                  │
# │                        ┆                     ┆ 984-8eba-c…                    ┆                  │
# │ …                      ┆ …                   ┆ …                              ┆ …                │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:check_missing ┆                  │
# │                        ┆                     ┆ _content_fn                    ┆                  │
# │ AWSLambda              ┆ us-west-2           ┆ arn:aws:lambda:us-west-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -reward-west-2-8c81eb5d-581a-4 ┆                  │
# │                        ┆                     ┆ 389-998b-5…                    ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:ingestion-eng ┆                  │
# │                        ┆                     ┆ ine-alex2-get-job-configs      ┆                  │
# │ AWSLambda              ┆ us-west-2           ┆ arn:aws:lambda:us-west-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -gc-west-2-e9cf0623-201d-47aa- ┆                  │
# │                        ┆                     ┆ 8b69-412e0…                    ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:archive-label ┆                  │
# │                        ┆                     ┆ -gdrive-DriveArchivistLambda-3 ┆                  │
# │                        ┆                     ┆ cvLnqiIgns…                    ┆                  │
# │ AWSLambda              ┆ us-west-1           ┆ arn:aws:lambda:us-west-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-ckr-con ┆                  │
# │                        ┆                     ┆ tact-us-west-1-a195e260-3461-4 ┆                  │
# │                        ┆                     ┆ e04-8114-6…                    ┆                  │
# │ AWSLambda              ┆ us-west-1           ┆ arn:aws:lambda:us-west-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -reward-west-1-ac002323-4de1-4 ┆                  │
# │                        ┆                     ┆ 802-b12e-f…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -order-east-1-79e395a2-5e12-48 ┆                  │
# │                        ┆                     ┆ b3-9162-79…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:CdkStepdefnSt ┆                  │
# │                        ┆                     ┆ arterStack-O-forwardlegacylamb ┆                  │
# │                        ┆                     ┆ daConst-Oz…                    ┆                  │
# │ AWSLambda              ┆ us-west-2           ┆ arn:aws:lambda:us-west-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-carlsjr ┆                  │
# │                        ┆                     ┆ -menu-west-2-22e3aa65-ff91-4e6 ┆                  │
# │                        ┆                     ┆ c-b305-92f…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -locata-east-1-f02b9485-b5af-4 ┆                  │
# │                        ┆                     ┆ ef8-9db8-5…                    ┆                  │
# │ AWSLambda              ┆ us-west-2           ┆ arn:aws:lambda:us-west-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:aaguiar-ldap  ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:document_pars ┆                  │
# │                        ┆                     ┆ ing_fn                         ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:2w-nr-muting- ┆                  │
# │                        ┆                     ┆ rules-automation-function      ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:ingestion-eng ┆                  │
# │                        ┆                     ┆ ine-evelyn3-get-job-configs    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:document_chun ┆                  │
# │                        ┆                     ┆ king_fn                        ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -reward-east-1-e609bd86-a68a-4 ┆                  │
# │                        ┆                     ┆ ab0-a54e-4…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -menu-east-1-f5765de4-1440-4ab ┆                  │
# │                        ┆                     ┆ 6-aa5b-014…                    ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:ingestion-eng ┆                  │
# │                        ┆                     ┆ ine-evelyn-get-job-configs     ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -offers-east-2-85d19673-2587-4 ┆                  │
# │                        ┆                     ┆ 18f-999d-9…                    ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:ollion-chatbo ┆                  │
# │                        ┆                     ┆ t-recursive-retriever-alpha    ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -locata-east-2-027df3f8-8fba-4 ┆                  │
# │                        ┆                     ┆ e72-8041-b…                    ┆                  │
# │ AWSLambda              ┆ us-west-2           ┆ arn:aws:lambda:us-west-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:aaguiar-ad-re ┆                  │
# │                        ┆                     ┆ ader                           ┆                  │
# │ AWSLambda              ┆ us-east-1           ┆ arn:aws:lambda:us-east-1:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -offers-east-1-1ff150e5-828a-4 ┆                  │
# │                        ┆                     ┆ ae6-88fb-d…                    ┆                  │
# │ AWSLambda              ┆ us-east-2           ┆ arn:aws:lambda:us-east-2:18794 ┆ Lambda ARN       │
# │                        ┆                     ┆ 0856853:function:cwsyn-hardees ┆                  │
# │                        ┆                     ┆ -order-east-2-0796f733-30e8-4b ┆                  │
# │                        ┆                     ┆ 8c-a774-72…                    ┆                  │
# └────────────────────────┴─────────────────────┴────────────────────────────────┴──────────────────┘

# %% [markdown]
# ## RDS Products

# %%
## get triplets of product code, region code, and resource id for Usage and SavingsPlanCoveredUsage
rds_df = df.filter((pl.col('line_item_product_code').eq('AmazonRDS')) &
                (pl.col('product_region_code').is_not_null()) &
                (pl.col('line_item_resource_id').is_not_null())
)
# usage_df = rds_df.filter(
#     (pl.col('line_item_line_item_type').is_in(['Usage', 'DiscountedUsage', 'SavingPlanCoveredUsage'])) &
#     (~pl.col('line_item_usage_type').str.contains('Bytes'))
# )
triplets_df = rds_df.select(["line_item_product_code",
                            "product_region_code",
                            "line_item_resource_id"
                            ])
triplets_df = triplets_df.unique()
triplets_df.sort(["product_region_code", "line_item_resource_id"])
triplets_df

resource_id_df = triplets_df.with_columns(
    resource_id_type = pl.when(pl.col('line_item_resource_id').str.contains(':cluster-snapshot:'))
    .then(pl.lit('Snapshot ARN'))
    .when(pl.col('line_item_resource_id').str.contains(':db:'))
    .then(pl.lit('Database ARN'))
    .when(pl.col('line_item_resource_id').str.contains(':cluster:'))
    .then(pl.lit('Cluster ARN'))
    .otherwise(pl.lit('Unknown'))
)
resource_id_df
# Out:
# shape: (13, 4)
# ┌────────────────────────┬─────────────────────┬────────────────────────────────┬──────────────────┐
# │ line_item_product_code ┆ product_region_code ┆ line_item_resource_id          ┆ resource_id_type │
# │ ---                    ┆ ---                 ┆ ---                            ┆ ---              │
# │ str                    ┆ str                 ┆ str                            ┆ str              │
# ╞════════════════════════╪═════════════════════╪════════════════════════════════╪══════════════════╡
# │ AmazonRDS              ┆ us-east-2           ┆ arn:aws:rds:us-east-2:18794085 ┆ Cluster ARN      │
# │                        ┆                     ┆ 6853:cluster:cluster-t3hrwc4gf ┆                  │
# │                        ┆                     ┆ 3zkly36x5diw5u6di              ┆                  │
# │ AmazonRDS              ┆ us-east-1           ┆ arn:aws:rds:us-east-1:18794085 ┆ Database ARN     │
# │                        ┆                     ┆ 6853:db:db-sql-rds-express     ┆                  │
# │ AmazonRDS              ┆ us-east-1           ┆ arn:aws:rds:us-east-1:18794085 ┆ Database ARN     │
# │                        ┆                     ┆ 6853:db:database-1             ┆                  │
# │ AmazonRDS              ┆ eu-north-1          ┆ arn:aws:rds:eu-north-1:1879408 ┆ Database ARN     │
# │                        ┆                     ┆ 56853:db:database-1-instance-1 ┆                  │
# │ AmazonRDS              ┆ eu-north-1          ┆ arn:aws:rds:eu-north-1:1879408 ┆ Cluster ARN      │
# │                        ┆                     ┆ 56853:cluster:cluster-6tcvzlm3 ┆                  │
# │                        ┆                     ┆ edthuwrnqvtmxrq5na             ┆                  │
# │ AmazonRDS              ┆ us-east-1           ┆ arn:aws:rds:us-east-1:18794085 ┆ Database ARN     │
# │                        ┆                     ┆ 6853:db:sql-rds-enterprise-not ┆                  │
# │                        ┆                     ┆ -encrypted                     ┆                  │
# │ AmazonRDS              ┆ us-west-2           ┆ arn:aws:rds:us-west-2:18794085 ┆ Database ARN     │
# │                        ┆                     ┆ 6853:db:dn-wordpress-database- ┆                  │
# │                        ┆                     ┆ replica                        ┆                  │
# │ AmazonRDS              ┆ eu-north-1          ┆ arn:aws:rds:eu-north-1:1879408 ┆ Snapshot ARN     │
# │                        ┆                     ┆ 56853:cluster-snapshot:databas ┆                  │
# │                        ┆                     ┆ e-1-final-snapshot             ┆                  │
# │ AmazonRDS              ┆ us-east-2           ┆ arn:aws:rds:us-east-2:18794085 ┆ Snapshot ARN     │
# │                        ┆                     ┆ 6853:cluster-snapshot:zw-poc-d ┆                  │
# │                        ┆                     ┆ b-final-snapshot               ┆                  │
# │ AmazonRDS              ┆ us-east-1           ┆ arn:aws:rds:us-east-1:18794085 ┆ Database ARN     │
# │                        ┆                     ┆ 6853:db:db-2-encrypted-restore ┆                  │
# │                        ┆                     ┆ d                              ┆                  │
# │ AmazonRDS              ┆ us-east-1           ┆ arn:aws:rds:us-east-1:18794085 ┆ Database ARN     │
# │                        ┆                     ┆ 6853:db:database-2-express     ┆                  │
# │ AmazonRDS              ┆ us-east-2           ┆ arn:aws:rds:us-east-2:18794085 ┆ Database ARN     │
# │                        ┆                     ┆ 6853:db:dn-wordpress-database  ┆                  │
# │ AmazonRDS              ┆ us-east-1           ┆ arn:aws:rds:us-east-1:18794085 ┆ Database ARN     │
# │                        ┆                     ┆ 6853:db:rds-sql-ha             ┆                  │
# └────────────────────────┴─────────────────────┴────────────────────────────────┴──────────────────┘

# %% [markdown]
# ## Redshift Products

# %%
red_df = df.filter((pl.col('line_item_product_code').eq('AmazonRedshift')) &
                (pl.col('product_region_code').is_not_null()) &
                (pl.col('line_item_resource_id').is_not_null())
)
triplets_df = red_df.select(["line_item_product_code", "product_region_code", "line_item_resource_id"])
triplets_df = triplets_df.unique()
triplets_df.sort(["product_region_code", "line_item_resource_id"])
triplets_df

resource_id_df = triplets_df.with_columns(
    resource_id_type = pl.when(pl.col('line_item_resource_id').str.contains(':cluster:'))
    .then(pl.lit('Cluster ARN'))
    .when(pl.col('line_item_resource_id').str.contains(':redshift-serverless:'))
    .then(pl.lit('Serverless ARN'))
    .otherwise(pl.lit('Unknown'))
)
resource_id_df
# Out:
# shape: (4, 4)
# ┌────────────────────────┬─────────────────────┬────────────────────────────────┬──────────────────┐
# │ line_item_product_code ┆ product_region_code ┆ line_item_resource_id          ┆ resource_id_type │
# │ ---                    ┆ ---                 ┆ ---                            ┆ ---              │
# │ str                    ┆ str                 ┆ str                            ┆ str              │
# ╞════════════════════════╪═════════════════════╪════════════════════════════════╪══════════════════╡
# │ AmazonRedshift         ┆ us-west-2           ┆ arn:aws:redshift:us-west-2:187 ┆ Cluster ARN      │
# │                        ┆                     ┆ 940856853:cluster:redshift-clu ┆                  │
# │                        ┆                     ┆ ster-1                         ┆                  │
# │ AmazonRedshift         ┆ us-east-1           ┆ arn:aws:redshift:us-east-1:187 ┆ Cluster ARN      │
# │                        ┆                     ┆ 940856853:cluster:redshift-clu ┆                  │
# │                        ┆                     ┆ ster-1                         ┆                  │
# │ AmazonRedshift         ┆ us-east-1           ┆ arn:aws:redshift-serverless:us ┆ Serverless ARN   │
# │                        ┆                     ┆ -east-1:187940856853:namespace ┆                  │
# │                        ┆                     ┆ /7005ab5e-d1da-457f-a1d8-508e0 ┆                  │
# │                        ┆                     ┆ 4c36eb3                        ┆                  │
# │ AmazonRedshift         ┆ us-east-1           ┆ arn:aws:redshift:us-east-1:999 ┆ Cluster ARN      │
# │                        ┆                     ┆ 537480004:cluster:source-to-65 ┆                  │
# │                        ┆                     ┆ 127672                         ┆                  │
# └────────────────────────┴─────────────────────┴────────────────────────────────┴──────────────────┘

# %% [markdown]
# ## ECR Products

# %%
ecr_df = df.filter((pl.col('line_item_product_code').eq('AmazonECR')) &
                (pl.col('product_region_code').is_not_null()) &
                (pl.col('line_item_resource_id').is_not_null())
)
triplets_df = ecr_df.select(["line_item_product_code", "product_region_code", "line_item_resource_id"])
triplets_df = triplets_df.unique()
triplets_df.sort(["product_region_code", "line_item_resource_id"])
triplets_df

# resource_id_df = triplets_df.with_columns(
#     resource_id_type = pl.when(pl.col('line_item_resource_id').str.contains(':cluster:'))
#     .then(pl.lit('Cluster ARN'))
#     .when(pl.col('line_item_resource_id').str.contains(':redshift-serverless:'))
#     .then(pl.lit('Serverless ARN'))
#     .otherwise(pl.lit('Unknown'))
# )
# resource_id_df
# Out:
# shape: (8, 3)
# ┌────────────────────────┬─────────────────────┬───────────────────────────────────────────────────┐
# │ line_item_product_code ┆ product_region_code ┆ line_item_resource_id                             │
# │ ---                    ┆ ---                 ┆ ---                                               │
# │ str                    ┆ str                 ┆ str                                               │
# ╞════════════════════════╪═════════════════════╪═══════════════════════════════════════════════════╡
# │ AmazonECR              ┆ ca-central-1        ┆ arn:aws:ecr:ca-central-1:187940856853:repository/ │
# │                        ┆                     ┆ ssmrepair841fc95a/ssmrepairfunctiona754f442repo   │
# │ AmazonECR              ┆ ap-southeast-1      ┆ arn:aws:ecr:ap-southeast-1:187940856853:repositor │
# │                        ┆                     ┆ y/rey-ecr                                         │
# │ AmazonECR              ┆ us-east-1           ┆ arn:aws:ecr:us-east-1:187940856853:repository/ccr │
# │                        ┆                     ┆ epl                                               │
# │ AmazonECR              ┆ us-west-2           ┆ arn:aws:ecr:us-west-2:187940856853:repository/foc │
# │                        ┆                     ┆ us_billing_pipeline_etl                           │
# │ AmazonECR              ┆ us-east-1           ┆ arn:aws:ecr:us-east-1:187940856853:repository/cdk │
# │                        ┆                     ┆ -hnb659fds-container-assets-187940856853-us-east- │
# │                        ┆                     ┆ 1                                                 │
# │ AmazonECR              ┆ us-east-1           ┆ arn:aws:ecr:us-east-1:187940856853:repository/say │
# │                        ┆                     ┆ -something                                        │
# │ AmazonECR              ┆ us-west-2           ┆ arn:aws:ecr:us-west-2:187940856853:repository/foc │
# │                        ┆                     ┆ us_convert                                        │
# │ AmazonECR              ┆ us-east-1           ┆ arn:aws:ecr:us-east-1:187940856853:repository/ccr │
# │                        ┆                     ┆ epl2                                              │
# └────────────────────────┴─────────────────────┴───────────────────────────────────────────────────┘
